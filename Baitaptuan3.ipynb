# %% [markdown]
# W3A1: Viet chuong trinh nhap vao n va in so dao nguoc cua n.

# %%
n = int(input())
rev = int(str(n)[::-1])
print(rev)
# Out:
# 4321

# %% [markdown]
# W3A2: Hoan doi hai so khong su dung bien tam thoi.

# %%
a, b = map(int, input().split())
a = a ^ b
b = b ^ a
a = a ^ b
print(a, b)
